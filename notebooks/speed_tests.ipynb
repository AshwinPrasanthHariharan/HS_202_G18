# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

import sys
sys.path.insert(0, '../')

from src.motion_analysis import OpticalFlow, SpeedEstimator, MotionUtils

print("Imports successful!")

# %% [markdown]
# ## Optical Flow Calculation

# %%
# Initialize optical flow calculator
flow_calc = OpticalFlow(method='farneback')
print("OpticalFlow initialized")

# %% [markdown]
# ## Speed Estimation

# %%
# Initialize speed estimator
speed_est = SpeedEstimator(pixels_per_meter=10.0, fps=30.0)
print("SpeedEstimator initialized")

# %% [markdown]
# ## Motion Utilities

# %%
# Test motion utility functions
# This section will contain motion utility tests
