# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

import sys
sys.path.insert(0, '../')

from src.visualization import HeatmapOverlay, RiskOverlay, Dashboard, AlertSystem
from src.utils import VisualizationUtils

print("Imports successful!")

# %% [markdown]
# ## Heatmap Overlay

# %%
# Initialize heatmap overlay
overlay = HeatmapOverlay(colormap='jet')
print("HeatmapOverlay initialized")

# %% [markdown]
# ## Risk Overlay

# %%
# Initialize risk overlay
risk_overlay = RiskOverlay()
print("RiskOverlay initialized")

# %% [markdown]
# ## Dashboard

# %%
# Initialize dashboard
dashboard = Dashboard(width=1920, height=1080)
print("Dashboard initialized")

# %% [markdown]
# ## Alert System

# %%
# Initialize alert system
alert_system = AlertSystem(log_file='../outputs/alert_logs/test_alerts.log')
print("AlertSystem initialized")
